# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.12.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.1)
# Requirement already satisfied: tokenizers>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.10.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.10.0+cu111)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.46)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)

# %%
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import svm
import re                                  
import string                             
from nltk.corpus import stopwords         
from nltk.stem import PorterStemmer        
from nltk.tokenize import TweetTokenizer   
from nltk.corpus import wordnet
from sentence_transformers import SentenceTransformer
from sklearn.metrics import classification_report

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def store_reviews(test_sentences):
  for i in range(len(test_sentences)):
    test_sentences[i] = test_sentences[i].lower()
    test_sentences[i] = test_sentences[i].replace('.','')
    test_sentences[i] = test_sentences[i].replace(',', ' ')
    # print(test_sentences[i])
  return test_sentences

# %%
def process_review(review):

    # remove hyperlinks
    review = re.sub(r'https?:\/\/.*[\r\n]*', '', review)

    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)

    review_tokens = tokenizer.tokenize(review)

    #removing stopwords and punctuations
    review_clean=[]
    for word in review_tokens:
        if (word not in stopwords.words('english') and word not in string.punctuation):
            review_clean.append(word)

    return ' '.join(review_clean)

# %%
def calc_accuracy(y_pred, labels):
  count = 0
  i=0
  wrong_test = []
  for pred,label in zip(y_pred,labels):
      if(pred == label):
          count+=1
      else:
        wrong_test.append(i)
      i+=1
  accuracy = 100*count/200
  return accuracy
# print('accuracy: ',before_attack)
# print(wrong_test)

# %%
def synonym(test_sentence,word):
    syn = list()
    
    for synset in wordnet.synsets(word):
        for lemma in synset.lemmas():
            if(lemma.name()!=word and '_' not in lemma.name()):
                adv_sentence = test_sentence.replace(word,lemma.name())
                sentence_embeddings = model.encode([test_sentence, adv_sentence])
                sim = cosine_similarity(
                    [sentence_embeddings[0]],
                    sentence_embeddings[1:]
                )
                if sim>0.80:
                  return lemma.name()

# %%
def generate_adv(test_data,tfidf_test):
  list_data = list(test_data['reviews'])
  feature_names = list(tfidfVectorizer.get_feature_names())
  adv_sentences = []
  for index in range(len(list_data)):
    sentence = list_data[index].split(' ')
    feature_vector = list(tfidf_test[index].T.todense())
    index_max = feature_vector.index(max(feature_vector))
    imp = feature_names[index_max]
    syn = synonym(test_sentences[index], imp)
    for i in range(len(sentence)):
      if(sentence[i]==imp and syn!=None):
        sentence[i]=syn
    list_data[index] = ' '.join(sentence)
    old_sentence = test_sentences[index].split(' ')
    adv_sentence = ''
    for j in range(len(old_sentence)):
      if old_sentence[j] == imp and syn!=None:
        adv_sentence += syn+' '
      else:
        adv_sentence += old_sentence[j]+' '
    adv_sentences.append(adv_sentence)
    print('old sentence: ',test_sentences[index])
    print('adversarial sentence: ' ,adv_sentence)
    print('-'*150)
  return list_data,adv_sentences

# %%
def build_model(model,train_x,train_y,test):
  model.fit(train_x,train_y)
  y_pred = model.predict(test)
  return y_pred

# %%
def identify_successful_attack(y_pred_adv,adv_data):
  i = 0
  wrong_adv = []
  for pred,actual in zip(y_pred_adv,adv_data['label']):
      if(pred != actual):
        wrong_adv.append(i)
      i+=1
  return wrong_adv

# %%
def visualize_attack(wrong_adv,wrong_test,test_sentences,adv_sentences,y_pred_test,y_pred_adv):
  indices_adv = [value for value in wrong_adv if value not in wrong_test]
  for i in indices_adv:
    print("old sentence: ",test_sentences[i], " --prediction: ",y_pred_test[i])
    print("adv sentence: ",adv_sentences[i]," --prediction:",y_pred_adv[i])
    print('-'*150)

# %% [markdown]
# ### Reading data from csv file

# %%
data = pd.read_csv('/content/drive/MyDrive/amazon_reviews.csv')
data.head
# Out:
# <bound method NDFrame.head of                                                reviews  label
# 0    So there is no way for me to plug it in here i...      0
# 1                          Good case, Excellent value.      1
# 2                               Great for the jawbone.      1
# 3    Tied to charger for conversations lasting more...      0
# 4                                    The mic is great.      1
# ..                                                 ...    ...
# 995  The screen does get smudged easily because it ...      0
# 996  What a piece of junk.. I lose more calls on th...      0
# 997                       Item Does Not Match Picture.      0
# 998  The only thing that disappoint me is the infra...      0
# 999  You can not answer calls with the unit, never ...      0
#
# [1000 rows x 2 columns]>

# %%
positive_reviews = data[data['label'] == 1]
negative_reviews = data[data['label'] == 0]
print('no. of positive reviews:',len(positive_reviews),'\nNo. of negative reviews', len(negative_reviews))
train_data = pd.concat([positive_reviews[0:400],negative_reviews[0:400]])
test_data = pd.concat([positive_reviews[400:], negative_reviews[400:]])
print('Length of training data:',len(train_data),'\nLength of testing data:', len(test_data))
train_sentences = list(train_data['reviews'])
test_sentences = list(test_data['reviews'])
test_sentences = store_reviews(test_sentences)
# Out:
# no. of positive reviews: 500
# No. of negative reviews 500
# Length of training data: 800
# Length of testing data: 200

# %% [markdown]
# ### Text pre-processing

# %%
train_data['reviews'] = train_data['reviews'].apply(process_review)
test_data['reviews'] = test_data['reviews'].apply(process_review)
train_data.head()
# Out:
#                       reviews  label
# 1   good case excellent value      1
# 2               great jawbone      1
# 4                   mic great      1
# 7         razr owner ... must      1
# 10        sound quality great      1

# %%
test_data.head()
# Out:
#                                                reviews  label
# 778                                         great deal      1
# 787                                    simple use like      1
# 788  great tool entertainment communication data ma...      1
# 791                        2 cases would order another      1
# 792                                        great phone      1

# %% [markdown]
# ### Vectorization

# %%
tfidfVectorizer = TfidfVectorizer(use_idf=True)
tfidf = tfidfVectorizer.fit(list(train_data['reviews']))
tfidf_train = tfidf.transform(list(train_data['reviews']))
tfidf_test = tfidf.transform(list(test_data['reviews']))
print('test data:',tfidf_test.shape)
print('train data: ',tfidf_train.shape)
# Out:
# test data: (200, 1550)
# train data:  (800, 1550)

# %% [markdown]
# ### Performing Adversarial perturbations

# %%
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
adv_data,adv_sentences = generate_adv(test_data,tfidf_test)
adv_df = pd.DataFrame({'reviews':adv_data,'label': test_data['label']})
adv_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# old sentence:  this is a great deal
# adversarial sentence:  this is a great deal
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it is simple to use and i like it
# adversarial sentence:  it is simpleton to use and i like it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it's a great tool for entertainment  communication  and data managementoh  be sure to use activesync 42 for optimal data synchronization results!
# adversarial sentence:  it's a great tool for entertainment  communication  and information managementoh  be sure to use activesync 42 for optimal information synchronization results!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i own 2 of these cases and would order another
# adversarial sentence:  i own 2 of these case and would order another
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  great phone
# adversarial sentence:  outstanding phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i bought this battery with a coupon from amazon and i'm very happy with my purchase
# adversarial sentence:  i bought this battery with a coupon from virago and i'm very happy with my purchase
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  perfect for the ps3
# adversarial sentence:  perfect for the ps3
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  five star plus  plus
# adversarial sentence:  five star plus  plus
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  a good quality bargain i bought this after i bought a cheapy from big lots that sounded awful and people on the other end couldn't hear me
# adversarial sentence:  a good quality bargain i buy this after i buy a cheapy from big lots that sounded awful and people on the other end couldn't hear me
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  good   works fine
# adversarial sentence:  good   works ok
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  for the price this was a great deal
# adversarial sentence:  for the price this was a great trade
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  great price  too!
# adversarial sentence:  great cost  too!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  yes it's shiny on front side - and i love it!
# adversarial sentence:  yes it's shiny on forepart side - and i love it!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the reception through this headset is excellent
# adversarial sentence:  the reception through this headset is excellent
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  2 thumbs up to this seller
# adversarial sentence:  2 thumbs up to this marketer
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have a verizon lg phone and they work well together  good reception and range that exceeds 20 feet line of sight
# adversarial sentence:  i have a verizon lg phone and they work well together  good reception and range that exceeds twenty feet line of sight
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  #1 it works - #2 it is comfortable
# adversarial sentence:  #1 it works - #2 it is comfy
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  battery charge-life is quite long
# adversarial sentence:  battery charge-life is rather long
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the jabra eargels fit my ears very well
# adversarial sentence:  the jabra eargels fit my ears very well
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  product is exactly as described
# adversarial sentence:  product is exactly as describe
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  gets a signal when other verizon phones won't
# adversarial sentence:  gets a signaling when other verizon phones won't
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i would recommend it
# adversarial sentence:  i would recommend it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  plan on ordering from them again and again
# adversarial sentence:  design on ordering from them again and again
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  that being said  for a phone  the camera is very nice; many cool effects to play with  and video is decent as well
# adversarial sentence:  that being said  for a phone  the camera is very nice; many cool effects to drama with  and video is decent as well
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have been very satisfied with this cell phone from day one
# adversarial sentence:  i have been very satisfied with this cell phone from daytime one
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  they keep getting better and better (this is my third one and i've had numerous palms too)
# adversarial sentence:  they keep getting improve and improve (this is my third one and i've had numerous palms too)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the shipping time was also very quick!
# adversarial sentence:  the shipping time was also very quick!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  good case!
# adversarial sentence:  good case!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  really good product
# adversarial sentence:  truly good product
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it looks very nice
# adversarial sentence:  it look very nice
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this is an excellent tool  especially when paired with your phone's auto-answer
# adversarial sentence:  this is an excellent tool  especially when paired with your phone's auto-answer
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have read other's reviews here but i haven't had any problem with it
# adversarial sentence:  i have read other's review here but i haven't had any problem with it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  comfortable in my hand
# adversarial sentence:  comfortable in my hand
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  (it works!)
# adversarial sentence:  (it works!)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  so far it has worked like a charm
# adversarial sentence:  so far it has worked like a charm
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have only had it for a few weeks  but so far  so good
# adversarial sentence:  i have only had it for a few week  but so far  so good
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  but  in any case  the best part is  you can download these pictures to your laptop using ir  or even send pictures from your laptop to the phone
# adversarial sentence:  but  in any case  the best part is  you can download these picture to your laptop using ir  or even send picture from your laptop to the phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  would recommend this item
# adversarial sentence:  would recommend this item
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it's been my choice headset for yearsgreat sound; good volume; good noise cancellation
# adversarial sentence:  it's been my choice headset for yearsgreat sound; goodness volume; goodness noise cancellation
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  nice case  feels good in your hands
# adversarial sentence:  nice case  feel good in your hands
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  just really good so far  probably the best bt headset i have ever had
# adversarial sentence:  just really good so far  probably the best bt headset i have ever had
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  works fine
# adversarial sentence:  works alright
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i received my headset in good time and was happy with it
# adversarial sentence:  i receive my headset in good time and was happy with it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i was very pleased to see that i could replace my well travled swivel holster for my blackberry flip
# adversarial sentence:  i was very pleased to see that i could replace my well travled swivel holster for my blackberry flip
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  my sister has one also and she loves it
# adversarial sentence:  my sister has one also and she love it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  good quality
# adversarial sentence:  good quality
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent dual-purpose headset
# adversarial sentence:  excellent dual-purpose headset
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent!
# adversarial sentence:  excellent!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it seems completely secure  both holding on to my belt  and keeping the iphone inside
# adversarial sentence:  it seems completely secure  both retention on to my belt  and keeping the iphone inside
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the only good thing was that it fits comfortably on small ears
# adversarial sentence:  the only good thing was that it fits well on small ears
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i am pairing this with my iphone  and i could not be happier with it so far
# adversarial sentence:  i am pairing this with my iphone  and i could not be happier with it so far
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  best headset ever!!!
# adversarial sentence:  best headset ever!!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it was that loudglad to say that the plantronics 510 maintains a flawless connection to my cell and with no static during normal use
# adversarial sentence:  it was that loudglad to say that the plantronics 510 maintains a flawless connexion to my cell and with no static during normal use
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  fits comfortably  came with three sizes of earbud tips
# adversarial sentence:  fits comfortably  came with three sizes of earbud tips
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent product for the price
# adversarial sentence:  splendid product for the price
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it was quite comfortable in the ear
# adversarial sentence:  it was rather comfortable in the ear
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  great phone
# adversarial sentence:  outstanding phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the pairing of the two devices was so easy it barely took a couple minutes before i started making calls with the voice dialing feature
# adversarial sentence:  the pairing of the two devices was so easy it hardly took a couple minutes before i started making calls with the voice dialing feature
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the cutouts and buttons are placed perfectly
# adversarial sentence:  the cutouts and buttons are put perfectly
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i love being able to use one headset for both by land-line and cell
# adversarial sentence:  i love being able to use one headset for both by land-line and cell
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  but despite these few flaws  this case is of exceptional quality and well worth the additional costs of owning an official oem product
# adversarial sentence:  but despite these few flaws  this case is of exceptional quality and well worth the extra costs of owning an official oem product
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i can hear while i'm driving in the car  and usually don't even have to put it on it's loudest setting
# adversarial sentence:  i can hear while i'm drive in the car  and usually don't even have to put it on it's loudest setting
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  seller shipped quickly and much cheaper than the competitors
# adversarial sentence:  seller shipped quickly and much cheap than the competitors
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  good show  samsung
# adversarial sentence:  good show  samsung
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  so i bought about 10 of these and saved alot of money
# adversarial sentence:  so i bought about ten of these and saved alot of money
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  leopard print is wonderfully wild!
# adversarial sentence:  leopard print is wonderfully wild!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  works for me
# adversarial sentence:  work for me
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  much better than the hard plastic cases
# adversarial sentence:  much better than the hard plastic case
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  happy so far!
# adversarial sentence:  happy so far!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  cool phone
# adversarial sentence:  coolheaded phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  works good
# adversarial sentence:  work good
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  motorola finally got the voice quality of a bluetooth headset right
# adversarial sentence:  motorola eventually got the voice quality of a bluetooth headset right
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  but it is great  i would really recommend it
# adversarial sentence:  but it is great  i would truly recommend it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  you get extra minutes so that you can carry out the call and not get cut off"
# adversarial sentence:  you acquire extra minutes so that you can carry out the call and not acquire cut off"
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the headset fulfills my requirements so i am happy with my purchase
# adversarial sentence:  the headset fulfills my requirements so i am felicitous with my purchase
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  logitech bluetooth headset is a 10!
# adversarial sentence:  logitech bluetooth headset is a 10!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i like the fact that it rests lightly against your ear  rather than inside
# adversarial sentence:  i like the fact that it rests lightly against your ear  instead than inside
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  a lot of websites have been rating this a very good phone and so do i
# adversarial sentence:  a batch of websites have been rating this a very good phone and so do i
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have tried these cables with my computer and my ipod and it works just fine
# adversarial sentence:  i have tried these cables with my calculator and my ipod and it works just fine
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it is easy to turn on and off when you are in the car and the volume controls are quite accessable
# adversarial sentence:  it is easy to turn on and off when you are in the car and the volume controls are rather accessable
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have had mine for about a year and this christmas i bought some for the rest of the family
# adversarial sentence:  i have had mine for about a year and this christmas i bought some for the rest of the household
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  otherwise  easy to install and use  clear sound
# adversarial sentence:  otherwise  easy to instal and use  clear sound
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  nice leather
# adversarial sentence:  nice leather
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it is a joy to use
# adversarial sentence:  it is a joy to usage
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  very satisifed with that
# adversarial sentence:  very satisifed with that
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this is the phone to get for 2005 i just bought my s710a and all i can say is wow!
# adversarial sentence:  this is the phone to get for 2005 i just bought my s710a and all i can state is wow!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  just reading on the specs alone makes you say wow
# adversarial sentence:  just reading on the specs lone makes you say wow
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  love it great armband
# adversarial sentence:  passion it great armband
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i really like this product over the motorola because it is allot clearer on the ear piece and the mic
# adversarial sentence:  i really like this product over the motorola because it is allot clearer on the ear piece and the mic
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i exchanged the sony ericson z500a for this and i'm pretty happy with that decision
# adversarial sentence:  i exchange the sony ericson z500a for this and i'm pretty happy with that decision
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i was very impressed with the price of the cases
# adversarial sentence:  i was very impressed with the price of the case
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  also makes it easier to hold on to
# adversarial sentence:  also makes it easy to hold on to
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i use this product in a motor control center where there is a lot of high voltage humming from the equipment  and it works great!
# adversarial sentence:  i use this product in a motor control center where there is a lot of heights voltage humming from the equipment  and it works great!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it's pretty easy
# adversarial sentence:  it's reasonably easy
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  beautiful styling though
# adversarial sentence:  beautiful styling though
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent product
# adversarial sentence:  splendid product
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it is the best charger i have seen on the market yet
# adversarial sentence:  it is the best charger i have seen on the marketplace yet
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  sweetest phone!!!
# adversarial sentence:  sweetest phone!!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  :-)oh  the charger seems to work fine
# adversarial sentence:  :-)oh  the charger seems to work fine
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal
# adversarial sentence:  it fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  doesn't work
# adversarial sentence:  doesn't work
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  unfortunately it did not work
# adversarial sentence:  alas it did not work
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  all three broke within two months of use
# adversarial sentence:  all 3 broke within two months of use
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  dont buy it
# adversarial sentence:  dont buy it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  my father has the v265  and the battery is dying
# adversarial sentence:  my father has the v265  and the battery is death
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  however  the ear pads come off easily and after only one week i lost one
# adversarial sentence:  however  the ear pads come off easily and after only 1 week i lost 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the calls drop  the phone comes on and off at will  the screen goes black and the worst of all it stops ringing intermittently
# adversarial sentence:  the calls bead  the phone comes on and off at will  the screen goes black and the worst of all it stops ringing intermittently
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  horrible  horrible protector
# adversarial sentence:  horrible  horrible protector
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i don't like this nokia either
# adversarial sentence:  i don't like this nokia either
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  reaching for the bottom row is uncomfortable  and the send and end keys are not where i expect them to be3
# adversarial sentence:  reaching for the underside row is uncomfortable  and the send and end keys are not where i expect them to be3
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i have bought this nokia cell phone a few weeks ago and it was a nightmare
# adversarial sentence:  i have bought this nokia cell phone a few weeks agone and it was a nightmare
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it would take too long to describe how bad my customer service experience has been with amazon
# adversarial sentence:  it would take too long to describe how bad my customer service see has been with amazon
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the only very disappointing thing was there was no speakerphone!!!!
# adversarial sentence:  the only very disappoint thing was there was no speakerphone!!!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  terrible my car will not accept this cassette
# adversarial sentence:  terrible my car will not take this cassette
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  product is useless  since it does not have enough charging current to charge the 2 cellphones i was planning to use it with
# adversarial sentence:  product is useless  since it does not have enough charge current to charge the 2 cellphones i was planning to use it with
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it's not what it says it is
# adversarial sentence:  it's not what it says it is
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  stay away from the q!
# adversarial sentence:  stay outside from the q!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  used and dirty
# adversarial sentence:  use and dirty
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  very unreliable service from t-mobile !
# adversarial sentence:  very undependable service from t-mobile !
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  not good enough for the price
# adversarial sentence:  not good sufficiency for the price
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i bought two of them and neither will charge
# adversarial sentence:  i bought two of them and neither will charge
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  these products cover up the important light sensor above the ear outlet
# adversarial sentence:  these products screen up the important light sensor above the ear outlet
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  just does not work
# adversarial sentence:  just does not function
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  poor reliability
# adversarial sentence:  hapless reliability
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  if i take a picture  the battery drops a bar  and starts beeping  letting me know its dieing
# adversarial sentence:  if i take a picture  the battery drops a barroom  and starts beeping  letting me know its dieing
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  terrible product  and waste of money!
# adversarial sentence:  awful product  and waste of money!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  last time buying from you
# adversarial sentence:  last time purchasing from you
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it was a waste of my money
# adversarial sentence:  it was a wastefulness of my money
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the item received was counterfeit
# adversarial sentence:  the item receive was counterfeit
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this is by far the worst purchase i've made on amazon
# adversarial sentence:  this is by far the worst purchase i've made on Amazon
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  does not work for listening to music with the cingular 8125
# adversarial sentence:  does not work for hearing to music with the cingular 8125
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the bottowm lineanother worthless  cheap gimmick from sprint
# adversarial sentence:  the bottowm lineanother worthless  cheap gimmick from sprint
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  having trouble with volume
# adversarial sentence:  having problem with volume
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  warning - do not buy!!
# adversarial sentence:  warn - do not buy!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  when it opens  the battery connection is broken and the device is turned off
# adversarial sentence:  when it opens  the battery connection is interrupt and the device is turned off
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i didn't want the clip going over the top of my ear  causing discomfort
# adversarial sentence:  i didn't want the clipping going over the top of my ear  causing discomfort
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  don't trust their website and don't expect any helpful support
# adversarial sentence:  don't trust their site and don't expect any helpful support
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the speaker is of low quality so as making the ring tones sound very cheap
# adversarial sentence:  the speaker is of low quality so as making the halo tones sound very cheap
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  bad reception
# adversarial sentence:  badness reception
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this product is very high quality chinese crap!!!!!!
# adversarial sentence:  this product is very high quality Chinese crap!!!!!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  don't buy this product - it fails!
# adversarial sentence:  don't bargain this product - it fails!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  everything about this product is wrongfirst
# adversarial sentence:  everything about this product is wrongfirst
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this was utterly confusing at first  which caused me to lose a couple of very  very important contacts
# adversarial sentence:  this was utterly confusing at first  which cause me to lose a couple of very  very important contacts
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  terrible phone holder
# adversarial sentence:  awful phone holder
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  problem is that the ear loops are made of weak material and break easily
# adversarial sentence:  problem is that the ear loops are made of weak material and interruption easily
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  not nearly as good looking as the amazon picture makes it look
# adversarial sentence:  not about as good looking as the amazon picture makes it look
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  how stupid is that?
# adversarial sentence:  how stupid is that?
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it always cuts out and makes a beep beep beep sound then says signal failed
# adversarial sentence:  it always cuts out and makes a beep beep beep sound then says signal fail
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  couldn't figure it out
# adversarial sentence:  couldn't figure it out
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  my phone sounded ok ( not great - ok)  but my wife's phone was almost totally unintelligible  she couldn't understand a word being said on it
# adversarial sentence:  my phone sounded ok ( not great - ok)  but my wife's phone was almost totally unintelligible  she couldn't understand a word being state on it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  so i had to take the battery out of the phone put it all back together and then restart it
# adversarial sentence:  so i had to return the battery out of the phone put it all back together and then restart it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  while i managed to bend the leaf spring back in place  the metal now has enough stress that it will break on the next drop
# adversarial sentence:  while i managed to bend the leaf spring back in place  the metal now has enough stress that it will interruption on the next drop
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  saggy  floppy piece of junk
# adversarial sentence:  saggy  floppy piece of debris
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it also had a new problem
# adversarial sentence:  it also had a new trouble
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it looses connection to the phone even when it is within a couple feet between the two
# adversarial sentence:  it looses connexion to the phone even when it is within a couple feet between the two
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  makes it easier to keep up with my bluetooth when i'm not wearing it
# adversarial sentence:  makes it easy to keep up with my bluetooth when i'm not wearing it
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  as i said abovepretty useless!
# adversarial sentence:  as i state abovepretty useless!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  never got it!!!!!
# adversarial sentence:  never got it!!!!!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this pair of headphones is the worst that i have ever had sound-wise
# adversarial sentence:  this pair of headphones is the worst that i have ever had sound-wise
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  [] down the drain because of a weak snap!
# adversarial sentence:  [] down the drainage because of a weak snap!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  does not charge the cingular (att) 8525 phone
# adversarial sentence:  does not charge the cingular (att) 8525 phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  however  after about a year  the fliptop started to get loose and wobbly and eventually my screen went black and i couldn't receive and place calls
# adversarial sentence:  however  after about a year  the fliptop started to get loose and wobbly and eventually my screen went black and i couldn't receive and spot calls
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i kept catching the cable on the seat and i had to pull the phone out to turn it on an off
# adversarial sentence:  i kept detection the cable on the seat and i had to pull the phone out to turn it on an off
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the mic there is a joke  and the volume is quite low
# adversarial sentence:  the mic there is a gag  and the volume is quite low
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i'm returning them
# adversarial sentence:  i'm return them
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i does not maintain a connection with the computer while it is on my lap
# adversarial sentence:  i does not maintain a connection with the computer while it is on my lap
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i had to purchase a different case
# adversarial sentence:  i had to purchase a unlike case
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  very much disappointed with this company
# adversarial sentence:  very much disappointed with this company
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it didn't charge for me
# adversarial sentence:  it didn't charge for me
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  buttons are too small
# adversarial sentence:  button are too small
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  however  the keypads are so tinny that i sometimes reach the wrong buttons
# adversarial sentence:  however  the keypads are so tinny that i sometimes reach the wrong buttons
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i cannot make calls at certain places
# adversarial sentence:  i cannot make calls at certain places
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  however  my girl was complain that some time the phone doesn't wake up like normal phone does
# adversarial sentence:  nevertheless  my girl was complain that some time the phone doesn't wake up like normal phone does
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this company charge me a restocking fee and still not given me my refund back
# adversarial sentence:  this company charge me a restocking fee and still not given me my repayment back
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i'm trying to return it for a refund
# adversarial sentence:  i'm trying to return it for a refund
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i plugged it in only to find out not a darn thing worked
# adversarial sentence:  i plug it in only to find out not a darn thing worked
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  earbud piece breaks easily
# adversarial sentence:  earbud piece break easily
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  lousy product
# adversarial sentence:  lousy merchandise
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  this phone tries very hard to do everything but fails at it's very ability to be a phone
# adversarial sentence:  this phone tries very hard to do everything but fails at it's very power to be a phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  not enough volume
# adversarial sentence:  not enough volume
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  echo problemvery unsatisfactory
# adversarial sentence:  Echo problemvery unsatisfactory
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  you could only take 2 videos at a time and the quality was very poor
# adversarial sentence:  you could only return 2 videos at a time and the quality was very poor
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  don't waste your money
# adversarial sentence:  don't wastefulness your money
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i am going to have to be the first to negatively review this product
# adversarial sentence:  i am going to have to be the first to negatively reappraisal this product
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  adapter does not provide enough charging current
# adversarial sentence:  adapter does not provide enough charge current
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  there was so much hype over this phone that i assumed it was the best  my mistake
# adversarial sentence:  there was so much hype over this phone that i assumed it was the best  my error
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  you also cannot take pictures with it in the case because the lense is covered
# adversarial sentence:  you also cannot take picture with it in the case because the lense is covered
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  phone falls out easily
# adversarial sentence:  telephone falls out easily
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it didn't work  people can not hear me when i talk
# adversarial sentence:  it didn't work  people can not hear me when i talking
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the text messaging feature is really tricky to use
# adversarial sentence:  the text messaging characteristic is really tricky to use
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i'm really disappointed all i have now is a charger that doesn't work
# adversarial sentence:  i'm really disappoint all i have now is a charger that doesn't work
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  painful on the ear
# adversarial sentence:  painful on the ear
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  lasted one day and then blew up
# adversarial sentence:  lasted one daytime and then blew up
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  disappointed
# adversarial sentence:  disappointed
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  kind of flops around
# adversarial sentence:  sort of flops around
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the screen does get smudged easily because it touches your ear and face
# adversarial sentence:  the screen does get smudged easily because it touches your ear and expression
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  what a piece of junk i lose more calls on this phone
# adversarial sentence:  what a piece of debris i lose more calls on this phone
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  item does not match picture
# adversarial sentence:  item does not catch picture
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the only thing that disappoint me is the infra red port (irda)
# adversarial sentence:  the only thing that disappoint me is the infra redness port (irda)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  you can not answer calls with the unit  never worked once!
# adversarial sentence:  you can not answer calls with the unit  ne'er worked once!
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                reviews  label
# 778                                         great deal      1
# 787                                 simpleton use like      1
# 788  great tool entertainment communication informa...      1
# 791                         2 case would order another      1
# 792                                  outstanding phone      1

# %% [markdown]
# ### SVM model

# %%
clf = svm.SVC(kernel='linear')
y_pred_svm = build_model(clf,tfidf_train,train_data['label'],tfidf_test)
y_true = test_data['label']
target_names = ['0','1']
print(classification_report(y_true, y_pred_svm,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81       100
#            1       0.86      0.70      0.77       100
#
#     accuracy                           0.80       200
#    macro avg       0.81      0.79      0.79       200
# weighted avg       0.81      0.80      0.79       200

# %%
tfidf_adv = tfidf.transform(list(adv_df['reviews']))
y_pred_svm_adv = clf.predict(tfidf_adv)
print(classification_report(y_true, y_pred_svm_adv,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75       100
#            1       0.80      0.59      0.68       100
#
#     accuracy                           0.72       200
#    macro avg       0.74      0.72      0.72       200
# weighted avg       0.74      0.72      0.72       200

# %% [markdown]
# ### Visualise Attack

# %%
wrong_svm = identify_successful_attack(y_pred_svm,adv_df)
wrong_svm_adv = identify_successful_attack(y_pred_svm_adv,adv_df)
visualize_attack(wrong_svm_adv,wrong_svm,test_sentences,adv_sentences,y_pred_svm,y_pred_svm_adv)
# Out:
# old sentence:  it is simple to use and i like it  --prediction:  1
# adv sentence:  it is simpleton to use and i like it   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  great phone  --prediction:  1
# adv sentence:  outstanding phone   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  2 thumbs up to this seller  --prediction:  1
# adv sentence:  2 thumbs up to this marketer   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  (it works!)  --prediction:  1
# adv sentence:  (it works!)   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent!  --prediction:  1
# adv sentence:  excellent!   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it seems completely secure  both holding on to my belt  and keeping the iphone inside  --prediction:  1
# adv sentence:  it seems completely secure  both retention on to my belt  and keeping the iphone inside   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it was quite comfortable in the ear  --prediction:  1
# adv sentence:  it was rather comfortable in the ear   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  great phone  --prediction:  1
# adv sentence:  outstanding phone   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the cutouts and buttons are placed perfectly  --prediction:  1
# adv sentence:  the cutouts and buttons are put perfectly   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  works for me  --prediction:  1
# adv sentence:  work for me   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  much better than the hard plastic cases  --prediction:  1
# adv sentence:  much better than the hard plastic case   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  cool phone  --prediction:  1
# adv sentence:  coolheaded phone   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  the headset fulfills my requirements so i am happy with my purchase  --prediction:  1
# adv sentence:  the headset fulfills my requirements so i am felicitous with my purchase   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it is easy to turn on and off when you are in the car and the volume controls are quite accessable  --prediction:  1
# adv sentence:  it is easy to turn on and off when you are in the car and the volume controls are rather accessable   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  excellent product  --prediction:  1
# adv sentence:  splendid product   --prediction: 0
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  very unreliable service from t-mobile !  --prediction:  0
# adv sentence:  very undependable service from t-mobile !   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  these products cover up the important light sensor above the ear outlet  --prediction:  0
# adv sentence:  these products screen up the important light sensor above the ear outlet   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  i didn't want the clip going over the top of my ear  causing discomfort  --prediction:  0
# adv sentence:  i didn't want the clipping going over the top of my ear  causing discomfort   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  bad reception  --prediction:  0
# adv sentence:  badness reception   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  don't buy this product - it fails!  --prediction:  0
# adv sentence:  don't bargain this product - it fails!   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  it also had a new problem  --prediction:  0
# adv sentence:  it also had a new trouble   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# old sentence:  however  my girl was complain that some time the phone doesn't wake up like normal phone does  --prediction:  0
# adv sentence:  nevertheless  my girl was complain that some time the phone doesn't wake up like normal phone does   --prediction: 1
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Naive Bayes model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(tfidf_train.toarray(), train_data['label'])
y_pred_nb = model.predict(tfidf_test.toarray())
print(classification_report(y_true,y_pred_nb))

# %%
y_pred_nb_adv = model.predict(tfidf_adv.toarray())
print(classification_report(y_true,y_pred_nb_adv))

# %%
wrong_nb = identify_successful_attack(y_pred_nb,adv_df)
wrong_nb_adv = identify_successful_attack(y_pred_nb_adv,adv_df)
visualize_attack(wrong_nb_adv,wrong_nb,test_sentences,adv_sentences,y_pred_nb,y_pred_nb_adv)
